# %% [markdown]
# # Práctica de laboratorio de visualización de datos

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Matplotlib - Ejercicios

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Escribir un programa que pregunte al usuario por las ventas de un rango de años y muestre por pantalla un diagrama de líneas con la evolución de las ventas.

# %%
ventas = []
ventas_con_desc = []
anios = [ "2022", "2023", "2024"]
print("Ventas por años desde 2020 al 2024")
for anio in anios:
    ventas.append(float(input(f"Año {anio}: ").strip()))
    ventas_con_desc.append(0.9 * ventas[-1])

ventas_df = pd.DataFrame({"ventas":ventas, "year": anios})

ventas_df
# Out:
# Ventas por años desde 2020 al 2024
# Año 2022: 890999
# Año 2023: 687789
# Año 2024: 468900
#      ventas  year
# 0  890999.0  2022
# 1  687789.0  2023
# 2  468900.0  2024

# %%
plt.hist(ventas_df['year'])
plt.show()

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Escribir una función que reciba una diccionario con las notas de las asignaturas de un curso y una cadena con el nombre de un color y devuelva un diagrama de barras de las notas en el color dado.

# %%
notas = {'Historia': 9, 'Taller': 7, 'Fisica':7, 'Lenguaje': 10}
def diagrama_barras_personalizado(notas, color):
    fig, ax = plt.subplots()
    notas_lista = list(notas.values())
    materias_lista = list(notas.keys())
    ax.bar(materias_lista, notas_lista, color = color)
    return ax

diagrama_barras_personalizado(notas, 'green')
# Out:
# <Axes: >

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Escribir una función que reciba una serie de Pandas con las notas de los alumnos de un curso y devuelva un diagrama de cajas con las notas. El diagrama debe tener el título "Distribución de notas".

# %%
notas_alumnos = pd.Series([9, 6, 3, 10, 8, 7])
def grafico_caja_notas(notas):
    fig, ax = plt.subplots()
    notas.plot(kind = 'box', ax = ax)
    plt.title('Distribución de notas')

grafico_caja_notas(notas_alumnos)

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Escribir una función que reciba una serie de Pandas con el número de ventas de un producto durante los meses de un trimestre y un título y cree un diagrama de sectores con las ventas en formato png con el titulo dado. El diagrama debe guardarse en un fichero con formato png y el título dado.

# %%
ventas_1_trimestre = {'Enero': 90000, 'Febrero': 110000, 'Marzo': 115000}

def diagrama_sectores_ventas(ventas, titulo_grafico):
    fig, ax = plt.subplots()
    ventas.plot(kind = 'pie', ax = ax)
    plt.ylabel('')
    plt.title(titulo_grafico)
    plt.savefig(titulo_grafico + '.png')
    return

s_ventas = pd.Series(ventas_1_trimestre)
diagrama_sectores_ventas(s_ventas, 'Ventas del primer trimestre')

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Escribir una función que reciba una serie de Pandas con el número de ventas de un producto por años y una cadena con el tipo de gráfico a generar (lineas, barras, sectores, areas) y devuelva un diagrama del tipo indicado con la evolución de las ventas por años y con el título "Evolución del número de ventas".

# %%
def diagrama_evolucion_ventas(ventas, tipo):
    fig, ax = plt.subplots()
    ventas.plot(kind = tipo, ax = ax)
    plt.title('Evolución del número de ventas')
    return ax

df_ventas = pd.Series([90000, 110000, 115000, 120000, 190000], index = [2020, 2021, 2022, 2023, 2024])
diagrama_evolucion_ventas(df_ventas, 'line')
plt.show()
diagrama_evolucion_ventas(df_ventas, 'bar')
plt.show()
diagrama_evolucion_ventas(df_ventas, 'pie')
plt.show()
diagrama_evolucion_ventas(df_ventas, 'area')
plt.show()

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# Escribir una función que reciba un dataframe de Pandas con los ingresos y gastos de una empresa por meses y devuelva un diagrama de líneas con dos líneas, una para los ingresos y otra para los gastos. El diagrama debe tener una leyenda identificando la línea de los ingresos y la de los gastos, un título con el nombre "Evolución de ingresos y gastos" y el eje y debe empezar en 0.

# %%
def diagrama_lineas_ingresos_gastos(datos_df):
    fig, ax = plt.subplots()
    datos_df.plot(ax = ax)
    ax.set_ylim([0, max(datos_df.Ingresos.max(), datos_df.Gastos.max()) + 500])
    plt.title('Evolución de ingresos y gastos')
    return ax

datos = {'Meses':['Enero', 'Febebro', 'Marzo', 'Abril'], 'Ingresos':[200000, 300000, 480000, 630000], 'Gastos':[92000, 43000, 74800, 56300]}
df_datos = pd.DataFrame(datos).set_index('Meses')
diagrama_lineas_ingresos_gastos(df_datos)
plt.show()
