# %% [markdown]
# # Seaborn

# %% [markdown]
#  Seaborn es una "envoltura" (wrapper) de alto nivel para Matplotlib

# %% [markdown]
# Construido sobre Matplotlib: Por debajo, Seaborn utiliza funciones de Matplotlib para dibujar los gráficos. No reemplaza a Matplotlib, sino que trabaja con él para hacerlo más fácil de usar.

# %% [markdown]
# Funciones Simplificadas: Ofrece funciones directas para crear gráficos estadísticos complejos (como diagramas de violín o mapas de calor) que en Matplotlib requerirían mucho más código y configuración manual.

# %% [markdown]
# Integración con Pandas: Está diseñado para funcionar de maravilla con los DataFrames de Pandas. Puedes pasar columnas enteras de un DataFrame directamente a los parámetros x e y de un gráfico, y Seaborn se encarga de todo el mapeo de datos.

# %% [markdown]
# Estética Mejorada: Viene con paletas de colores y estilos visuales predeterminados que hacen que los gráficos se vean más modernos y legibles desde el primer momento, sin necesidad de personalización.

# %% [markdown]
# ## Tipos de gráficos

# %% [markdown]
# Seaborn organiza sus gráficos por el tipo de información que quieres visualizar. Aquí están las categorías principales y algunos ejemplos populares

# %% [markdown]
# Gráficos Relacionales
# Para ver la relación entre dos variables numéricas.
#  - scatterplot(): El clásico diagrama de puntos para ver correlaciones.
#  - lineplot(): Ideal para visualizar la evolución de una variable a lo largo del tiempo.

# %% [markdown]
# Gráficos de Distribución
# Para entender cómo se distribuyen los datos de una sola variable.
# - histplot(): El histograma, para ver la frecuencia de los valores en intervalos.
# - kdeplot(): Gráfico de densidad, una versión suavizada del histograma.
# - ecdfplot(): Muestra la función de distribución acumulada empírica.

# %% [markdown]
# Gráficos Categóricos
# Para comparar una variable numérica a través de diferentes categorías.
# - boxplot(): El diagrama de caja y bigotes, perfecto para ver la mediana, cuartiles y valores atípicos.
# - violinplot(): Combina un boxplot con un gráfico de densidad (KDE), mostrando la distribución de los datos en cada categoría.
# - barplot(): El clásico diagrama de barras para mostrar una métrica (como la media) por categoría.
# - countplot(): Similar a un barplot, pero cuenta las ocurrencias de cada categoría.

# %% [markdown]
# Gráficos de Regresión
# Son gráficos relacionales que además incluyen un modelo de regresión lineal para mostrar la tendencia.
# - lmplot(): Dibuja un scatterplot y ajusta una línea de regresión.

# %% [markdown]
# Gráficos Matriciales heatmap
# Para visualizar datos en formato de matriz, a menudo usando colores para representar valores.
# - heatmap(): Muy útil para visualizar matrices de correlación o datos tabulados.
# - clustermap(): Como un mapa de calor, pero reordena las filas y columnas para agrupar elementos similares.

# %% [markdown]
# Datasets almacenados
# Seaborn incluye varios datasets clásicos que son muy útiles para practicar y aprender. No necesitas descargar ningún archivo CSV, simplemente los cargas con una función. Para ver la lista completa, puedes usar el código sns.get_dataset_names().

# %% [markdown]
# ## Importación de librerías

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %% [markdown]
# Se importa un dataset ya existente en la librería

# %%
tips = sns.load_dataset('tips')

sns.set(style='dark', palette='dark')

# %% [markdown]
# <h2>Stripplot y swarmplot

# %% [markdown]
# Ambos gráficos, stripplot y swarmplot, se usan para visualizar la distribución de una variable numérica a través de diferentes categorías. Son   como diagramas de dispersión (scatterplots) para datos categóricos.

# %%
sns.stripplot(data=tips, x='day', y='total_bill', hue='smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips, x='day', y='total_bill', hue='smoker', dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='smoker', dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# <h2>Gráficas combinadas</h2>

# %%
sns.boxplot(data=tips, x='day', y='total_bill', hue='smoker', dodge=True)
sns.swarmplot(data=tips, x='day', y='total_bill', hue='smoker', dodge=True, color='yellow', marker='*')
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:yellow'` for same effect.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# <h2>Violín</h2>
# <p>Es una gráfica parecida a boxplot, pero en lugar de cuartiles, muestra la concentración de datos. Admite función <b>split</b> para comparar variables categóricas.</p>

# %%
sns.violinplot(data=tips, x='day', y='total_bill', hue='smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
#split
sns.violinplot(data=tips, x='day', y='total_bill', hue='smoker', split=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# <h2>Catplot</h2>
# <p>Podemos combinar con otra variable usando <b>col</b> y seleccionar el tipo de gráfica con kind: </p>
# <ul>
# <li>strip (default)</li>
# <li>swarm</li>
# <li>box</li>
# <li>violin</li>
# <li>boxen</li>
# <li>point</li>
# <li>bar</li>
# <li>count</li>
# <ul>

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', dodge=True, col='time', kind='violin')

# %% [markdown]
# <h2>Pairplot</h2>
# <p>Correalciones todas las variables numéricas entre sí.</p>
# <p>Podemos eliminar las gráficas repetidas.</p>

# %%
sns.pairplot(data=tips)

# %%
# Eliminamos gráficas repetidas
sns.pairplot(data=tips, corner = True)
