# %% [markdown]
# # TP N°1 Regresión Lineal y Polinómica
# * Dado el conjunto de datos, plantear una regresión lineal (grado 1) y analizar si ese modelo es el óptimo para los datos dados.
# * Luego plantear una regresión polinómica (defina el grado del polinomio que mejor se adpate a los datos)
# * Realice para todos los casos, el grafi simultáneo de los datos y el modelo generado.
# * Analizar resultados.

# %% [markdown]
# ## 1. Conjunto de Datos

# %%
import numpy as np #Librería numérica
import matplotlib.pyplot as plt # Para crear gráficos con matplotlib
# %matplotlib inline
# Si quieres hacer estos gráficos dentro de un jupyter notebook
from sklearn.linear_model import LinearRegression #Regresión Lineal con scikit-learn

# %% [markdown]
# creamos elk conjunto de datos, usando f(x)

# %%
def f(x):  # función f(x) = 0.1*x + 1.25 + 0.2*Ruido_Gaussiano
    np.random.seed(42) # para poder reproducirlo
    y = 0.1*x + 1.25 + 0.2*np.random.randn(x.shape[0])
    return y

x = np.arange(0, 20, 0.5) # generamos valores x de 0 a 20 en intervalos de 0.5
y = f(x) # calculamos y a partir de la función que hemos generado

# hacemos un gráfico de los datos que hemos generado
plt.scatter(x,y,label='data', color='blue')
plt.title('Datos');

# %% [markdown]
# Dimensiones de los conjuntos x e y

# %%
print(f"Dimension eje y {y.shape}, tipo de dato: {type(y.shape)}")
print(y)
print(f"Dimension eje x {x.shape}, tipo de dato: {type(x.shape)}")
print(x)
# Out:
# Dimension eje y (40,), tipo de dato: <class 'tuple'>
# [1.34934283 1.27234714 1.47953771 1.70460597 1.40316933 1.45317261
#  1.86584256 1.75348695 1.55610512 1.80851201 1.65731646 1.70685405
#  1.89839245 1.51734395 1.60501643 1.88754249 1.84743378 2.16284947
#  1.96839518 1.91753926 2.54312975 2.25484474 2.36350564 2.11505036
#  2.34112346 2.52218452 2.31980128 2.6751396  2.52987226 2.64166125
#  2.62965868 3.17045564 2.84730056 2.68845781 3.11450898 2.75583127
#  3.09177272 2.70806598 2.88436279 3.23937225]
# Dimension eje x (40,), tipo de dato: <class 'tuple'>
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12.  12.5 13.  13.5
#  14.  14.5 15.  15.5 16.  16.5 17.  17.5 18.  18.5 19.  19.5]

# %% [markdown]
# ## 2. Regresión Lineal
# Importamos la clase de Regresión Lineal de scikit-learn

# %%
from sklearn.linear_model import LinearRegression

regresion_lineal = LinearRegression()

x = x.reshape(-1,1)
x.shape
# Out:
# (40, 1)

# %%
# Predecimos los valores y para los datos usados en el entrenamiento
prediccion_entrenamiento = regresion_lineal.fit(x,y)
w, b = prediccion_entrenamiento.coef_[0],prediccion_entrenamiento.intercept_
prediccion_entrenamiento = regresion_lineal.predict(x)

# %%
print("predicciones del modelo")
print(prediccion_entrenamiento)
print('funcion del modelo')
print ('f(x)= ',w,"x", "+" ,b)
# Out:
# predicciones del modelo
# [1.28587925 1.33179686 1.37771447 1.42363208 1.46954969 1.5154673
#  1.56138491 1.60730252 1.65322013 1.69913774 1.74505534 1.79097295
#  1.83689056 1.88280817 1.92872578 1.97464339 2.020561   2.06647861
#  2.11239622 2.15831383 2.20423144 2.25014905 2.29606666 2.34198426
#  2.38790187 2.43381948 2.47973709 2.5256547  2.57157231 2.61748992
#  2.66340753 2.70932514 2.75524275 2.80116036 2.84707797 2.89299558
#  2.93891318 2.98483079 3.0307484  3.07666601]
# funcion del modelo
# f(x)=  0.0918352184351532 x + 1.2858792525736682

# %% [markdown]
# ## Calculamos el Error Cuadrático Medio
# MSE = Mean Squared Error

# %%
# importamos el cálculo del error cuadrático medio (MSE)
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_true = y, y_pred = prediccion_entrenamiento)
# La raíz cuadrada del MSE es el RMSE
rmse = np.sqrt(mse)
print('Error Cuadrático Medio (MSE) = ' + str(mse))
print('Raíz del Error Cuadrático Medio (RMSE) = ' + str(rmse))
# Out:
# Error Cuadrático Medio (MSE) = 0.03318522012927899
# Raíz del Error Cuadrático Medio (RMSE) = 0.18216810952875093

# %%
# Predecimos los valores y para los datos usados en el entrenamiento
prediccion_entrenamiento = regresion_lineal.predict(x.reshape(-1,1))

mse = mean_squared_error(y_true = y, y_pred = prediccion_entrenamiento)
# La raíz cuadrada del MSE es el RMSE
rmse = np.sqrt(mse)
print('Error Cuadrático Medio (MSE) = ' + str(mse))
print('Raíz del Error Cuadrático Medio (RMSE) = ' + str(rmse))
# Out:
# Error Cuadrático Medio (MSE) = 0.03318522012927899
# Raíz del Error Cuadrático Medio (RMSE) = 0.18216810952875093

# %%
# calculamos el coeficiente de determinación R2
r2 = regresion_lineal.score(x.reshape(-1,1), y)
print('Coeficiente de Determinación R2 = ' + str(r2))
# Out:
# Coeficiente de Determinación R2 = 0.8943593637683117

# %% [markdown]
# Tengo 3 valores de error el MSE, el RMSE y el R2, con valores distintos, pero como ¿para una función de error el modelo es mejor que para otra función de error?
#
# Indicar el valor de los parámetros calculados para el modelo.

# %%
plt.scatter(x,y)
prediccion = regresion_lineal.predict(x.reshape(-1,1))
plt.plot(x,prediccion,'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 3. Regresión Polinómica
# Definir el grado del polinomio

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
# definir el grado del polinomio
polinomio_xxxx = PolynomialFeatures(degree=2, include_bias=False) # completar xxxx con el grado del polinomio

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x, y, "b.")  # círculos azules
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
polinomio_xxxx.fit(x.reshape(-1,1))
# Out:
# PolynomialFeatures(include_bias=False)

# %%
x_ = polinomio_xxxx.transform(x.reshape(-1,1))

# %%
x_ # verificamos que se haya calculado correctamente x_
# Out:
# array([[0.0000e+00, 0.0000e+00],
#        [5.0000e-01, 2.5000e-01],
#        [1.0000e+00, 1.0000e+00],
#        [1.5000e+00, 2.2500e+00],
#        [2.0000e+00, 4.0000e+00],
#        [2.5000e+00, 6.2500e+00],
#        [3.0000e+00, 9.0000e+00],
#        [3.5000e+00, 1.2250e+01],
#        [4.0000e+00, 1.6000e+01],
#        [4.5000e+00, 2.0250e+01],
#        [5.0000e+00, 2.5000e+01],
#        [5.5000e+00, 3.0250e+01],
#        [6.0000e+00, 3.6000e+01],
#        [6.5000e+00, 4.2250e+01],
#        [7.0000e+00, 4.9000e+01],
#        [7.5000e+00, 5.6250e+01],
#        [8.0000e+00, 6.4000e+01],
#        [8.5000e+00, 7.2250e+01],
#        [9.0000e+00, 8.1000e+01],
#        [9.5000e+00, 9.0250e+01],
#        [1.0000e+01, 1.0000e+02],
#        [1.0500e+01, 1.1025e+02],
#        [1.1000e+01, 1.2100e+02],
#        [1.1500e+01, 1.3225e+02],
#        [1.2000e+01, 1.4400e+02],
#        [1.2500e+01, 1.5625e+02],
#        [1.3000e+01, 1.6900e+02],
#        [1.3500e+01, 1.8225e+02],
#        [1.4000e+01, 1.9600e+02],
#        [1.4500e+01, 2.1025e+02],
#        [1.5000e+01, 2.2500e+02],
#        [1.5500e+01, 2.4025e+02],
#        [1.6000e+01, 2.5600e+02],
#        [1.6500e+01, 2.7225e+02],
#        [1.7000e+01, 2.8900e+02],
#        [1.7500e+01, 3.0625e+02],
#        [1.8000e+01, 3.2400e+02],
#        [1.8500e+01, 3.4225e+02],
#        [1.9000e+01, 3.6100e+02],
#        [1.9500e+01, 3.8025e+02]])

# %%
model = LinearRegression().fit(x_, y)

# %%
print(f"coefficients: {model.coef_}")
# Out:
# coefficients: [0.06930422 0.00115544]

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: 1.357227421206376

# %%
r_sq = model.score(x_, y)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 0.8981252474760002

# %%
# Representación gráfica de la función hipótesis generada
x1 = np.arange(0,20,1)
y1 = model.coef_[0]*x1+model.coef_[1]*x1**2+model.intercept_
plt.plot(x1, y1, "g-")  # estilo de linea solida verde
plt.plot(x, y, "b.")  # círculos azules
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Grado 1

# %%
# definir el grado del polinomio
polinomio_grado_1 = PolynomialFeatures(degree=1, include_bias=False) # completar xxxx con el grado del polinomio

# %%
polinomio_grado_1.fit(x.reshape(-1,1))
# Out:
# PolynomialFeatures(degree=1, include_bias=False)

# %%
x_ = polinomio_grado_1.transform(x.reshape(-1,1))

# %%
model = LinearRegression().fit(x_, y)

# %%
r_sq = model.score(x_, y)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 0.8943593637683117

# %%
# Representación gráfica de la función hipótesis generada
x1 = np.arange(0,20,1)
y1 = model.coef_[0]*x1 + model.intercept_
plt.plot(x1, y1, "g-")  # estilo de linea solida verde
plt.plot(x, y, "b.")  # círculos azules
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Conclusiones:
# * ¿Cual es el modelo con el cual obtenemos el mejor resultado?
